# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as pp
import pandas as pd
import seaborn
# %matplotlib inline

# %%
import zipfile
zipfile.ZipFile('names.zip').extractall('.')
